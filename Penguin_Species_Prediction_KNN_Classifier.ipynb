# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Machine Learning/Project - 2 (Penguin dataset)/Dataset/penguins_size.csv')

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
## Problem Statement:
# The goal of this analysis is to build a machine learning model that can predict the species of a penguin
# based on its physical characteristics and location. This is a classification problem where the model
# will learn patterns from the data to assign penguins to one of the three species: Adelie, Gentoo, or Chinstrap.

## Features and Target:

# Target Variable - species -> The species of the penguin (Adelie, Gentoo, Chinstrap). This is what we want to predict.

# Features - island, culmen_length_mm, culmen_depth_mm, flipper_length_mm, body_mass_g, sex

# %%
data = df.copy()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ##  Exploratory Data Analysis

# %%
data.isna().sum()
## There are null values in the dataset
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
# drop null values of dataframe "data" which are less in number

data = data.dropna()
data.isna().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
duplicates = data.duplicated()
print(duplicates.sum())  # Count of duplicates
# Out:
# 0

# %%
data.shape
# Out:
# (334, 7)

# %%
data.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
data.describe()
## Observations
# culmen_length_mm and flipper_length_mm are approximately symmetrical
# culmen_depth_mm is symmetrical with slight variability
# body_mass_g is slightly right-skewed
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        333.000000       333.000000         333.000000   333.000000
# mean          43.992793        17.164865         200.966967  4207.057057
# std            5.468668         1.969235          14.015765   805.215802
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.500000        15.600000         190.000000  3550.000000
# 50%           44.500000        17.300000         197.000000  4050.000000
# 75%           48.600000        18.700000         213.000000  4775.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
data.select_dtypes(include=['object']).nunique()
# Out:
# species    3
# island     3
# sex        3
# dtype: int64

# %%
data.species.unique()
# The Species of Penguin (e.g.,'Adelie', 'Chinstrap', 'Gentoo')
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
# Count of each penguin species
data['species'].value_counts()
# Out:
# species
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: count, dtype: int64

# %%
data.island.unique()
# Name of the islands (e.g.,'Torgersen', 'Biscoe', 'Dream')
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
# Count of each island
data['island'].value_counts()
# Out:
# island
# Biscoe       164
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
data.sex.unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
# Count of each Gender
data['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %%
# Remove rows in the 'sex' column that contain '.'
data = data[data['sex'] != '.']

# %%
data.describe(include=['O'])
## Observations
# species has 3 unique categories with Adelie being the most common
# island has 3 unique locations with Biscoe being the most frequent
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  MALE
# freq       146     163   168

# %% [markdown]
# ## Univariate Analysis

# %%
def cont_vis_analysis(data,col):
  ## visualisation of continuous numerical variable
  fig,axes=plt.subplots(1,3,figsize=(8,3),layout='constrained')
  fig.suptitle('Continuous Data Distributions')

  axes[0].set_title('Histogram')
  sns.histplot(data[col],ax=axes[0])

  axes[1].set_title('KDE plot')
  sns.kdeplot(data[col],ax=axes[1])

  axes[2].set_title('Boxplot')
  sns.boxplot(data[col],ax=axes[2])

  fig.show()

def cont_non_vis_analysis(data,col):
  ## Non visual analaysis of continuous numerical data
  series=data[col]
  print(series.agg(['count','min','max','mean','median','var','std','skew','kurt']).round(2))
  print()

# %%
print("Non Visual Analysis")
cont_non_vis_analysis(data,'culmen_length_mm')
print("Visual Analysis")
cont_vis_analysis(data,'culmen_length_mm')
# Out:
# Non Visual Analysis
# count     333.00
# min        32.10
# max        59.60
# mean       43.99
# median     44.50
# var        29.91
# std         5.47
# skew        0.05
# kurt       -0.88
# Name: culmen_length_mm, dtype: float64
#
# Visual Analysis

# %%
## Observations in "culmen_length_mm"
# 1. Penguin's culmen length data has no outliers
# 2. Skewness is 0.05 → very slight positive skew, almost symmetrical
# 3. Kurtosis is -0.88 → distribution is slightly flat (platykurtic) compared to normal

# %%
print("Non Visual Analysis")
cont_non_vis_analysis(data,'culmen_depth_mm')
print("Visual Analysis")
cont_vis_analysis(data,'culmen_depth_mm')
# Out:
# Non Visual Analysis
# count     333.00
# min        13.10
# max        21.50
# mean       17.16
# median     17.30
# var         3.88
# std         1.97
# skew       -0.15
# kurt       -0.89
# Name: culmen_depth_mm, dtype: float64
#
# Visual Analysis

# %%
## Observations in "culmen_depth_mm"
# 1. Penguin's culmen depth data has no outliers
# 2. Skewness is -0.15 → slight negative skew, but very close to symmetrical
# 3. Kurtosis is -0.89 → slightly flat (platykurtic) distribution

# %%
print("Non Visual Analysis")
cont_non_vis_analysis(data,'flipper_length_mm')
print("Visual Analysis")
cont_vis_analysis(data,'flipper_length_mm')
# Out:
# Non Visual Analysis
# count     333.00
# min       172.00
# max       231.00
# mean      200.97
# median    197.00
# var       196.44
# std        14.02
# skew        0.36
# kurt       -0.96
# Name: flipper_length_mm, dtype: float64
#
# Visual Analysis

# %%
## Observations in "flipper_length_mm"
# 1. Length of penguin's flipper data has no outliers
# 2. Skewness is 0.36 → moderate positive skew, confirming a slight tail on the right
# 3. Kurtosis is -0.96 → distribution is flatter than a normal curve (platykurtic)

# %%
print("Non Visual Analysis")
cont_non_vis_analysis(data,'body_mass_g')
print("Visual Analysis")
cont_vis_analysis(data,'body_mass_g')
# Out:
# Non Visual Analysis
# count        333.00
# min         2700.00
# max         6300.00
# mean        4207.06
# median      4050.00
# var       648372.49
# std          805.22
# skew           0.47
# kurt          -0.73
# Name: body_mass_g, dtype: float64
#
# Visual Analysis

# %%
## Observations in "body_mass_g"
# 1. Mass of the penguin in grams data has no outliers
# 2. Skewness is 0.47 → moderate positive skew, indicating heavier penguins are pulling the distribution right
# 3. Kurtosis is -0.73 → distribution is slightly flat (platykurtic) compared to normal

# %% [markdown]
# ## Kurtosis:
#
# - Zero excess kurtosis (≈ 0): The distribution is mesokurtic, meaning its tails and peak are similar to those of a normal distribution.
#
# - Positive excess kurtosis (> 0): Indicates a leptokurtic distribution, with a sharper peak and heavier tails.
#
# - Negative excess kurtosis (< 0): Indicates a platykurtic distribution, with a flatter peak and lighter tails.

# %%
def catg_disc_analysis(data,col):
  print("Value Counts for ",col)
  print(data[col].value_counts())
  print("Null values =",data[col].isna().sum())
  fig,axes=plt.subplots(1,2,figsize=(8,3),layout='constrained')
  fig.suptitle('Categorical / Discrete Num Data Distributions')

  axes[0].set_title('Bar Plot')
  sns.countplot(x=col,data=data,ax=axes[0])

  axes[1].set_title('Pie Chart')
  vc_data=data[col].value_counts()
  axes[1].pie(vc_data,labels=vc_data.index,autopct='%1.1f%%')
  fig.show()

# %%
data.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
catg_disc_analysis(data,'species')
# Out:
# Value Counts for  species
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64
# Null values = 0

# %%
catg_disc_analysis(data,'island')
# Out:
# Value Counts for  island
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64
# Null values = 0

# %%
catg_disc_analysis(data,'sex')
# Out:
# Value Counts for  sex
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64
# Null values = 0

# %%
sns.pairplot(data, hue='species')

# %%
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [333 rows x 7 columns]

# %%
sns.kdeplot(x='culmen_length_mm',data=data,hue='species')
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
# compute avg culmen_length for every species
data.groupby('species')['culmen_length_mm'].mean()
# Out:
# species
# Adelie       38.823973
# Chinstrap    48.833824
# Gentoo       47.568067
# Name: culmen_length_mm, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %%
## Cont-Cont
def cont_cont_bivar_analysis(data,col1,col2,hue='species'):
  print(f"Covariance = {data[col1].cov(data[col2])}")
  print(f"Correlation = {data[col1].corr(data[col2])}")
  sns.scatterplot(x=col1,y=col2,data=data,hue='species')
  plt.show()

# %%
cont_cont_bivar_analysis(data,'culmen_length_mm','culmen_depth_mm')
# Out:
# Covariance = -2.4620913383262817
# Correlation = -0.22862563591302934

# %%
# cont - cat bivariate
def cont_cat_bivar_analysis(data,cat_col,num_col):
  sns.boxplot(x=cat_col,y=num_col,data=data)

# %%
cont_cat_bivar_analysis(data,'species','culmen_length_mm')

# %%
## Observations
# There is no outliers present while plotting between species and culmen length
# Average of Chinstrap species culmen lengthis more compare to other

# %%
cont_cat_bivar_analysis(data,'species','culmen_depth_mm')

# %%
## Observations
# There is one outlier present in Adelie species while plotting between species and culmen_depth

# %%
cont_cat_bivar_analysis(data,'species','flipper_length_mm')

# %%
## Observations
# There are two outlier present in Adelie species while plotting between species and flipper length

# %%
cont_cat_bivar_analysis(data,'species','body_mass_g')

# %%
## Observations
# There are two outlier present in Chinastrap species while plotting between species and body mass
# Average body mass of Adelie and Chinstrap species are nearly same

# %%
## cat - cat bivariate
def cat_cat_bivar_analysis(data,col1,col2):
  ct_data=pd.crosstab(data[col1],data[col2])
  ct_data.plot(kind='bar')

# %%
cat_cat_bivar_analysis(data,'species','island')

# %%
## Observations
# Only Adelie species found in three islands

# %%
cat_cat_bivar_analysis(data,'species','sex')

# %% [markdown]
# ## Label Encoding

# %%
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [333 rows x 7 columns]

# %%
## One hot encoding
data_encoded=pd.get_dummies(data,columns=['sex'])
data_encoded
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g  sex_FEMALE  sex_MALE
# 0         3750.0       False      True
# 1         3800.0        True     False
# 2         3250.0        True     False
# 4         3450.0        True     False
# 5         3650.0       False      True
# ..           ...         ...       ...
# 338       4925.0        True     False
# 340       4850.0        True     False
# 341       5750.0       False      True
# 342       5200.0        True     False
# 343       5400.0       False      True
#
# [333 rows x 8 columns]

# %%
## label encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() # create an object of LabelEncoder class
data_encoded['island_encode']=le.fit_transform(data_encoded['island'])
data_encoded
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g  sex_FEMALE  sex_MALE  island_encode
# 0         3750.0       False      True              2
# 1         3800.0        True     False              2
# 2         3250.0        True     False              2
# 4         3450.0        True     False              2
# 5         3650.0       False      True              2
# ..           ...         ...       ...            ...
# 338       4925.0        True     False              0
# 340       4850.0        True     False              0
# 341       5750.0       False      True              0
# 342       5200.0        True     False              0
# 343       5400.0       False      True              0
#
# [333 rows x 9 columns]

# %%
data_encoded.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g  sex_FEMALE  sex_MALE  island_encode
# 0       3750.0       False      True              2
# 1       3800.0        True     False              2
# 2       3250.0        True     False              2
# 4       3450.0        True     False              2
# 5       3650.0       False      True              2

# %%
data_encoded.drop(['island'],axis=1,inplace=True)

# %%
data_encoded
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie              39.1             18.7              181.0
# 1    Adelie              39.5             17.4              186.0
# 2    Adelie              40.3             18.0              195.0
# 4    Adelie              36.7             19.3              193.0
# 5    Adelie              39.3             20.6              190.0
# ..      ...               ...              ...                ...
# 338  Gentoo              47.2             13.7              214.0
# 340  Gentoo              46.8             14.3              215.0
# 341  Gentoo              50.4             15.7              222.0
# 342  Gentoo              45.2             14.8              212.0
# 343  Gentoo              49.9             16.1              213.0
#
#      body_mass_g  sex_FEMALE  sex_MALE  island_encode
# 0         3750.0       False      True              2
# 1         3800.0        True     False              2
# 2         3250.0        True     False              2
# 4         3450.0        True     False              2
# 5         3650.0       False      True              2
# ..           ...         ...       ...            ...
# 338       4925.0        True     False              0
# 340       4850.0        True     False              0
# 341       5750.0       False      True              0
# 342       5200.0        True     False              0
# 343       5400.0       False      True              0
#
# [333 rows x 8 columns]

# %%
# Using features predict Species of Penguin
x=data_encoded.drop('species',axis=1) ## features
y=data_encoded['species'] ## target
x.shape,y.shape
# Out:
# ((333, 7), (333,))

# %%
## KNN model is distance based ML model
## Sensitive to features scales
## Feature scaling is must for this model

# %% [markdown]
# ## Model with Feature Scaling
# ### StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_trans=sc.fit_transform(x)
x = pd.DataFrame(x_trans,columns=x.columns)
x
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0           -0.896042         0.780732          -1.426752    -0.568475
# 1           -0.822788         0.119584          -1.069474    -0.506286
# 2           -0.676280         0.424729          -0.426373    -1.190361
# 3           -1.335566         1.085877          -0.569284    -0.941606
# 4           -0.859415         1.747026          -0.783651    -0.692852
# ..                ...              ...                ...          ...
# 328          0.587352        -1.762145           0.931283     0.892957
# 329          0.514098        -1.457000           1.002739     0.799674
# 330          1.173384        -0.744994           1.502928     1.919069
# 331          0.221082        -1.202712           0.788372     1.234995
# 332          1.081817        -0.541564           0.859828     1.483749
#
#      sex_FEMALE  sex_MALE  island_encode
# 0     -0.991031  0.991031       1.889392
# 1      1.009050 -1.009050       1.889392
# 2      1.009050 -1.009050       1.889392
# 3      1.009050 -1.009050       1.889392
# 4     -0.991031  0.991031       1.889392
# ..          ...       ...            ...
# 328    1.009050 -1.009050      -0.913136
# 329    1.009050 -1.009050      -0.913136
# 330   -0.991031  0.991031      -0.913136
# 331    1.009050 -1.009050      -0.913136
# 332   -0.991031  0.991031      -0.913136
#
# [333 rows x 7 columns]

# %% [markdown]
# ### Train_Test_Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
## shuffle = True is good to have in train test split
## it removes any sorting order in data, which helps in getting a better random sample

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (266, 7) (266,)
# (67, 7) (67,)

# %% [markdown]
# ## Import KNN algorithm class

# %%
## Import KNN classification model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# Fit the model
knn.fit(x_train, y_train) ## stored data points in model
# compute model performance on training data

# Model performance on test data
# Make predictions on the test set
y_pred = knn.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred) ## prec, rec, f1 score

# %%
y_train_pred = knn.predict(x_train)
print("Train Accuracy:", accuracy_score(y_train, y_train_pred))
# Out:
# Train Accuracy: 0.9962406015037594

# %%
print(f"Test Accuracy: {accuracy}")
print("Classification Report:")
print(class_report)
# Out:
# Test Accuracy: 0.9850746268656716
# Classification Report:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      0.97      0.98        31
#    Chinstrap       0.93      1.00      0.96        13
#       Gentoo       1.00      1.00      1.00        23
#
#     accuracy                           0.99        67
#    macro avg       0.98      0.99      0.98        67
# weighted avg       0.99      0.99      0.99        67

# %%
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# Try values of K from 1 to 20
k_range = range(1, 21)
cv_scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, x_train, y_train, cv=5, scoring='accuracy')  # 5-fold CV
    cv_scores.append(scores.mean())

# Plotting accuracy vs K
plt.plot(k_range, cv_scores)
plt.xlabel('K value')
plt.ylabel('Cross-Validated Accuracy')
plt.title('KNN Classifier - Choosing Best K')
plt.show()

# Best K
best_k = k_range[cv_scores.index(max(cv_scores))]
print("Best K value:", best_k)
# Out:
# Best K value: 4
